# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import sqlalchemy

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
website="https://www.justia.com/lawyers/california/san-francisco"

# %% [markdown]
# #### Get Request

# %%
response=requests.get(website)

# %% [markdown]
# #### Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Soup Object

# %%
soup=BeautifulSoup(response.content, "html.parser")
#soup

# %% [markdown]
# ### Results

# %%
results=soup.findAll("div",{"data-vars-action":"OrganicListing"})

# %%
len(results)
# Out:
# 40

# %% [markdown]
# ### Target necessary data

# %%
# Name
# Short Bio
# Specialization
# University
# Address
# Phone
# Email Link

# %% [markdown]
# #### Name

# %%
results[0].find("strong",{"class":"lawyer-name"}).get_text().strip()
# Out:
# 'Doug Bend'

# %% [markdown]
# #### Short Bio

# %%
results[0].find("div",{"class":"lawyer-expl"}).get_text().strip()
# Out:
# 'San Francisco, CA Attorney'

# %% [markdown]
# #### Specialization

# %%
results[0].find("span",{"class":"-practices"}).get_text()
# Out:
# 'Business, Entertainment & Sports, Real Estate and Trademarks'

# %% [markdown]
# #### University

# %%
results[0].find("span",{"class":"-law-schools"}).get_text()
# Out:
# 'Georgetown University Law Center'

# %% [markdown]
# #### Address

# %%
results[0].find("span",{"class":"-address"}).get_text().strip().replace("\t","").replace("\n","")
# Out:
# '2181 Greenwich StreetSan Francisco,CA 94123'

# %% [markdown]
# #### Phone

# %%
results[0].find("strong",{"class":"-phone"}).get_text().strip()
# Out:
# '(415) 633-6841'

# %% [markdown]
# #### Email Link

# %%
results[0].find("a",{"class":"-email"}).get("href")
# Out:
# 'https://lawyers.justia.com/lawyer/doug-bend-1662623/contact'

# %% [markdown]
# ### Put everything together inside a For-Loop

# %%
name=[]
short_bio=[]
specialization=[]
university=[]
address=[]
phone=[]
email_link=[]
for result in results:
    #name
    try:
        name.append(result.find("strong",{"class":"lawyer-name"}).get_text().strip())
    except:
        name.append("")
    #short_bio
    try:
        short_bio.append(result.find("div",{"class":"lawyer-expl"}).get_text().strip())
    except:
        short_bio.append("")
    #specialization
    try:
        specialization.append(result.find("span",{"class":"-practices"}).get_text())
    except:
        specialization.append("")
    #university
    try:
        university.append(result.find("span",{"class":"-law-schools"}).get_text())
    except:
        university.append("")
    #address
    try:
        address.append(result.find("strong",{"class":"lawyer-name"}).get_text().strip())
    except:
        address.append("")
    #phone
    try:
        phone.append(result.find("strong",{"class":"-phone"}).get_text().strip())
    except:
        phone.append("")
    #email link
    try:
        email_link.append(result.find("a",{"class":"-email"}).get("href"))
    except:
        email_link.append("")

# %% [markdown]
# ### Create Pandas Dataframe

# %%
lawyers_df=pd.DataFrame({"lawyer_name":name,
                        "short_bio":short_bio,
                        "specialization":specialization,
                        "university":university,
                        "address":address,
                        "phone":phone,
                        "email_link":email_link})

# %%
lawyers_df
# Out:
#                 lawyer_name  \
# 0                 Doug Bend
# 1                  Sam Amin
# 2         Pezhman Pakneshan
# 3    Christopher F. Morales
# 4          Sweta Khandelwal
# 5         Richard Alexander
# 6              Marin Cionca
# 18  https://lawyers.justia.com/lawyer/adam-garrard...
# 19  https://lawyers.justia.com/lawyer/matt-a-sulli...
# 20
# 21  https://lawyers.justia.com/lawyer/alexander-ku...
# 22  https://lawyers.justia.com/lawyer/feras-mousil...
# 23  https://lawyers.justia.com/lawyer/michael-lee-...
# 24  https://lawyers.justia.com/lawyer/rahman-popal...
# 25  https://lawyers.justia.com/lawyer/arnold-isaac...
# 26  https://lawyers.justia.com/lawyer/garrett-sutt...
# 27  https://lawyers.justia.com/lawyer/michael-paul...
# 28  https://lawyers.justia.com/lawyer/vaughan-de-k...
# 29  https://lawyers.justia.com/lawyer/gregory-j-br...
# 30  https://lawyers.justia.com/lawyer/jon-welner-1...
# 31  https://lawyers.justia.com/lawyer/john-michael...
# 32  https://lawyers.justia.com/lawyer/joseph-toben...
# 33  https://lawyers.justia.com/lawyer/michael-elli...
# 34  https://lawyers.justia.com/lawyer/reno-f-r-fer...
# 35  https://lawyers.justia.com/lawyer/valerie-fenc...
# 36  https://lawyers.justia.com/lawyer/randall-h-sc...
# 37  https://lawyers.justia.com/lawyer/sonya-tien-1...
# 38  https://lawyers.justia.com/lawyer/paul-deangel...
# 39  https://lawyers.justia.com/lawyer/shawn-kerend...

# %% [markdown]
# ### Output in Excel

# %%
lawyers_df.to_excel("lawyers_single.xlsx", index=False)

# %% [markdown]
# ### Part 2 - Pagination - Scrape 20 Pages

# %%
name=[]
short_bio=[]
specialization=[]
university=[]
address=[]
phone=[]
email_link=[]
for i in range(1,21):
    website="https://www.justia.com/lawyers/california/san-francisco?page="+str(i)
    response=requests.get(website)
    soup=BeautifulSoup(response.content, "html.parser")
    results=soup.findAll("div",{"data-vars-action":"OrganicListing"})
    for result in results:
        #name
        try:
            name.append(result.find("strong",{"class":"lawyer-name"}).get_text().strip())
        except:
            name.append("")
        #short_bio
        try:
            short_bio.append(result.find("div",{"class":"lawyer-expl"}).get_text().strip())
        except:
            short_bio.append("")
        #specialization
        try:
            specialization.append(result.find("span",{"class":"-practices"}).get_text())
        except:
            specialization.append("")
        #university
        try:
            university.append(result.find("span",{"class":"-law-schools"}).get_text())
        except:
            university.append("")
        #address
        try:
            address.append(result.find("strong",{"class":"lawyer-name"}).get_text().strip())
        except:
            address.append("")
        #phone
        try:
            phone.append(result.find("strong",{"class":"-phone"}).get_text().strip())
        except:
            phone.append("")
        #email link
        try:
            email_link.append(result.find("a",{"class":"-email"}).get("href"))
        except:
            email_link.append("")
            
lawyers_multiple_df=pd.DataFrame({"lawyer_name":name,
                        "short_bio":short_bio,
                        "specialization":specialization,
                        "university":university,
                        "address":address,
                        "phone":phone,
                        "email_link":email_link})

# %%
lawyers_multiple_df
# Out:
#                    lawyer_name  \
# 0                 Marin Cionca
# 1       Christopher F. Morales
# 2             Debra Schoenberg
# 3                    Doug Bend
# 4           Randall H Scarlett
# ..                         ...
# 795  Alexander Fredrick Harper
# 796            Bruce J. Napell
# 797     Arete Rita Kostopoulos
# 798        Kimberly A. Madigan
# 799         Erich Gerard Keefe
#
#                                              short_bio  \
# 0    San Francisco, CA Attorney with 14 years of ex...
# 1    San Francisco, CA Lawyer with 30 years of expe...
# 2    San Francisco, CA Attorney with 34 years of ex...
# 3                           San Francisco, CA Attorney
# 4                           San Francisco, CA Attorney
# ..                                                 ...
# 795     Oakland, CA Lawyer with 16 years of experience
# 796  San Rafael, CA Attorney with 37 years of exper...
# 797                                 Oakland, CA Lawyer
# 798  Redwood City, CA Lawyer with 19 years of exper...
# 799  Berkeley, CA Attorney with 18 years of experience
#
#                                         specialization  \
# 0                           IP, Patents and Trademarks
# 1                           Criminal, DUI and Juvenile
# 2                                   Divorce and Family
# 3    Business, Entertainment & Sports, Real Estate ...
# 4    Asbestos, Civil Rights, Consumer and Personal ...
# ..                                                 ...
# 795                         Criminal, DUI and Juvenile
# 796                                           Business
# 797                                         Bankruptcy
# 798                                 Divorce and Family
# 799                                        Immigration
#
#                                             university  \
# 0                                   Concord Law School
# 1                       Santa Clara Univ School of Law
# 2            University of New Hampshire School of Law
# 3                     Georgetown University Law Center
# 4                 Golden Gate University School of Law
# ..                                                 ...
# 795                              University of Florida
# 796  University of California Hastings College of t...
# 797                  Wayne State University Law School
# 798                                    Univ of Alberta
# 799                       New Coll of CA School of Law
#
#                        address           phone  \
# 0                 Marin Cionca  (800) 454-1360
# 1       Christopher F. Morales  (415) 552-1215
# 2             Debra Schoenberg  (415) 834-1120
# 3                    Doug Bend  (415) 633-6841
# 4           Randall H Scarlett  (415) 688-2176
# ..                         ...             ...
# 795  Alexander Fredrick Harper  (510) 250-9477
# 796            Bruce J. Napell  (415) 460-0100
# 797     Arete Rita Kostopoulos  (510) 270-2782
# 798        Kimberly A. Madigan  (650) 482-8480
# 799         Erich Gerard Keefe  (510) 717-5996
#
#                                             email_link
# 0    https://lawyers.justia.com/lawyer/marin-cionca...
# 1    https://lawyers.justia.com/lawyer/christopher-...
# 2    https://lawyers.justia.com/lawyer/debra-schoen...
# 3    https://lawyers.justia.com/lawyer/doug-bend-16...
# 4    https://lawyers.justia.com/lawyer/randall-h-sc...
# ..                                                 ...
# 795  https://lawyers.justia.com/lawyer/alexander-fr...
# 796  https://lawyers.justia.com/lawyer/bruce-j-nape...
# 797  https://lawyers.justia.com/lawyer/arete-rita-k...
# 798  https://lawyers.justia.com/lawyer/kimberly-a-m...
# 799  https://lawyers.justia.com/lawyer/erich-gerard...
#
# [800 rows x 7 columns]

# %% [markdown]
# #### Excel

# %%
lawyers_multiple_df.to_excel("lawyers_multiple.xlsx", index=False)

# %% [markdown]
# #### Postgres

# %%
#create sqlalchemy engine
engine=sqlalchemy.create_engine('postgresql://postgres:12345@localhost:5432')
lawyers_multiple_df.to_sql("lawyers",engine,index=False)
